# %% [markdown]
# # Exercise 1
# ## Support Vector Machines
# Perception is an important step for autonomous systems. We will look into one method of classifying data given a dataset containing inputs and corresponding targets. In this case we will look at the [Iris dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set), but it could be any arbitrary dataset.
#
# Today we will work with classification using [Support Vector Machines (SVM)](https://en.wikipedia.org/wiki/Support-vector_machine).
# We will use the implementation from the `sklearn` library.
#
# **Note**: If the import of the `pandas` library fails because the module isn't installed, install the `pandas` library with pip.

# %%
import sklearn as sk
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np

# Helper function for plotting the fit of your SVM.
def plot_fit(X, y, clf):
    """
    X = samples
    y = Ground truth
    clf = trained model
    """
    h = .02
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    fig = plt.figure(1, figsize=(8, 6))
    plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm, edgecolors= "black")
    plt.xlabel('Sepal length')
    plt.ylabel('Sepal width')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())

# %% [markdown]
# As mentioned previously, we're using the Iris dataset. It consists of 150 samples with 4 featuers each.
# We're using the sepal length and the sepal width as features to predict which species of the Iris flower one sample is.
# The target classes are integer-encoded.

# %%
# Import some data to play with
iris = sk.datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
display(iris_df)
X = iris_df.iloc[:,:2]
display(X)
y = iris.target
print("Number of samples ::", X.shape[0])
print("Number of features ::", X.shape[1])
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
#      sepal length (cm)  sepal width (cm)
# 0                  5.1               3.5
# 1                  4.9               3.0
# 2                  4.7               3.2
# 3                  4.6               3.1
# 4                  5.0               3.6
# ..                 ...               ...
# 145                6.7               3.0
# 146                6.3               2.5
# 147                6.5               3.0
# 148                6.2               3.4
# 149                5.9               3.0
#
# [150 rows x 2 columns]
# Number of samples :: 150
# Number of features :: 2

# %% [markdown]
# ## Pandas
# We will use pandas to manage our data.
# Initially we will only use the two first data points, i.e. the sepal length and sepal width.
#
# We plot the data and we can see all our samples

# %%
fig1 = plt.figure(1, figsize=(8, 6))
ax = plt.scatter(X['sepal length (cm)'], X["sepal width (cm)"], c=y)
plt.xlabel('sepal length (cm)')
plt.ylabel("sepal width (cm)")
plt.legend(*ax.legend_elements(), title='Target label')
plt.show()

# %% [markdown]
# ## Normalization.
# Using `sklearn.preprocessing` we can normalize the data to have zero mean and unitary variance.
# Why could that be important?
# ```{Python}
# X_scaled = StandardScaler().fit_transform(X)
# ```
# Plot the data, did you succed with normalizing the data?

# %%
###
# code here
###

X_scaled = StandardScaler().fit_transform(X)
df_scaled = pd.DataFrame(X_scaled)
df_scaled.columns = ['sepal length (cm)', 'sepal width (cm)']
df_scaled

fig1 = plt.figure(1, figsize=(8, 6))
ax = plt.scatter(df_scaled['sepal length (cm)'], df_scaled["sepal width (cm)"], c=y)
plt.xlabel('sepal length (cm)')
plt.ylabel("sepal width (cm)")
plt.legend(*ax.legend_elements(), title='Target label')
plt.show()

# %% [markdown]
# ### Training / testing split.
# We now create a training and testing set.
# The training set is to train our model and the testing set is to make sure we don't overfit to the data. We can use the test set to analyze this.
#
# You can use the following function to create your training and testing split:
# ```{Python}
# train_test_split(data, target, test_size=n)
# ```

# %%
###
# code here
###

X_train, X_test, y_train, y_test = train_test_split(df_scaled, y, test_size = 0.2)

# %% [markdown]
# ## Train and test the accuracy of your model
# Using `LinearSVC` from `sklearn`:
# ```{Python}
# sk.svm.LinearSVC(penalty='l2', loss='squared_hinge', random_state=0, max_iter=10e4)
# ```
# [Documentation for LinearSVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html?highlight=linearsvc#sklearn.svm.LinearSVC)
#
# You can test the accuracy of your trained model with:
# ```{}
# clf.score(X_train, y_train)
# clf.score(X_test, y_test)
# ```
#
# And finally, plot your fit with the provided plot function `plot_fit`

# %%
X_train_np = X_train.values if hasattr(X_train, 'values') else X_train
X_test_np = X_test.values if hasattr(X_test, 'values') else X_test

clf = LinearSVC(penalty='l2', loss='squared_hinge', random_state=0, max_iter=100000)
clf.fit(X_train_np, y_train)

train_accuracy = clf.score(X_train_np, y_train) * 100
test_accuracy = clf.score(X_test_np, y_test) * 100

print(f"Training Accuracy: {train_accuracy:.2f} %")
print(f"Test Accuracy: {test_accuracy:.2f} %")

plot_fit(X_train_np, y_train, clf)
# Out:
# Training Accuracy: 80.83 %
# Test Accuracy: 73.33 %

# %% [markdown]
# ## Exercises
# ### 1) Kernel
# First exersice is to try other kernels than the linear:
# ```{python}
# svc = svm.SVC(kernel='linear', C=C)
# rbf_svc = svm.SVC(kernel='rbf', gamma=gamma, C=C))
# poly_svc = svm.SVC(kernel='poly', degree=degree, C=C))
# ```
# [SVC documentation](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html)
#
# Do you get better results?
# ### 2 ) More dimensions
# Now use 3 features for each sample. So either you add the petal length or petal width as an additional feature.
#
# Can you get a better fit?
#
# Can you visualize your predictions?
# Make a 3D scatterplot with colors for each predicted class.
# ```{Python}
# fig = plt.figure(1, figsize=(10, 8))
# ax = Axes3D(fig, elev=-150, azim=110)
# ax.scatter(x, y, z, c=class_vector)
# ```
#
# ### 3) Even more dimensions
# Finally try fitting the classifier with all features, i.e. 4 features per sample.

# %% [markdown]
# ### 1) Kernel

# %%
from sklearn.svm import SVC

# %%
X_train_np = X_train.values if hasattr(X_train, 'values') else X_train
X_test_np = X_test.values if hasattr(X_test, 'values') else X_test

#clf = LinearSVC(penalty='l2', loss='squared_hinge', random_state=0, max_iter=100000)
clf = SVC(kernel = 'rbf', gamma = 0.1, C = 10.0)
clf.fit(X_train_np, y_train)

train_accuracy = clf.score(X_train_np, y_train) * 100
test_accuracy = clf.score(X_test_np, y_test) * 100

print(f"Training Accuracy: {train_accuracy:.2f} %")
print(f"Test Accuracy: {test_accuracy:.2f} %")

plot_fit(X_train_np, y_train, clf)
# Out:
# Training Accuracy: 83.33 %
# Test Accuracy: 73.33 %

# %%
X_train_np = X_train.values if hasattr(X_train, 'values') else X_train
X_test_np = X_test.values if hasattr(X_test, 'values') else X_test

#clf = LinearSVC(penalty='l2', loss='squared_hinge', random_state=0, max_iter=100000)
clf = SVC(kernel = 'poly', degree = 5, C = 10)
clf.fit(X_train_np, y_train)

train_accuracy = clf.score(X_train_np, y_train) * 100
test_accuracy = clf.score(X_test_np, y_test) * 100

print(f"Training Accuracy: {train_accuracy:.2f} %")
print(f"Test Accuracy: {test_accuracy:.2f} %")

plot_fit(X_train_np, y_train, clf)
# Out:
# Training Accuracy: 76.67 %
# Test Accuracy: 70.00 %

# %% [markdown]
# Indeed, the first offered kernel (excluding the linear one) provides us with slightly better results.

# %% [markdown]
# ### 2. More dimensions

# %%
# Import some data to play with
iris = sk.datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
display(iris_df)
X = iris_df.iloc[:,:3]
display(X)
y = iris.target
print("Number of samples ::", X.shape[0])
print("Number of features ::", X.shape[1])
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
#      sepal length (cm)  sepal width (cm)  petal length (cm)
# 0                  5.1               3.5                1.4
# 1                  4.9               3.0                1.4
# 2                  4.7               3.2                1.3
# 3                  4.6               3.1                1.5
# 4                  5.0               3.6                1.4
# ..                 ...               ...                ...
# 145                6.7               3.0                5.2
# 146                6.3               2.5                5.0
# 147                6.5               3.0                5.2
# 148                6.2               3.4                5.4
# 149                5.9               3.0                5.1
#
# [150 rows x 3 columns]
# Number of samples :: 150
# Number of features :: 3

# %%
X_scaled = StandardScaler().fit_transform(X)
df_scaled = pd.DataFrame(X_scaled, columns=['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)'])

fig1 = plt.figure(1, figsize=(8, 6))
scatter = plt.scatter(df_scaled['sepal length (cm)'], df_scaled["sepal width (cm)"], c=y, cmap='viridis')
plt.xlabel('sepal length (cm)')
plt.ylabel("sepal width (cm)")

plt.colorbar(scatter, label='Target label')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(df_scaled, y, test_size = 0.2)

# %%
from sklearn.metrics import accuracy_score
from mpl_toolkits.mplot3d import Axes3D

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

clf = LinearSVC(penalty='l2', loss='squared_hinge', random_state=0, max_iter=100000)
clf.fit(X_scaled, y)
train_accuracy = accuracy_score(y, clf.predict(X_scaled)) * 100

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(X_scaled[:, 0], X_scaled[:, 1], X_scaled[:, 2], c=y, cmap='viridis', edgecolor='k')

x_min, x_max = X_scaled[:, 0].min() - 1, X_scaled[:, 0].max() + 1
y_min, y_max = X_scaled[:, 1].min() - 1, X_scaled[:, 1].max() + 1
z_min, z_max = X_scaled[:, 2].min() - 1, X_scaled[:, 2].max() + 1

xx, yy = np.meshgrid(np.linspace(x_min, x_max, 30),
                     np.linspace(y_min, y_max, 30))

w = clf.coef_[0]
b = clf.intercept_[0]
zz = -(w[0] * xx + w[1] * yy + b) / w[2]

ax.plot_surface(xx, yy, zz, color='blue', alpha=0.3, rstride=100, cstride=100)
ax.set_xlabel('Sepal Length (cm)')
ax.set_ylabel('Sepal Width (cm)')
ax.set_zlabel('Petal Length (cm)')
fig.colorbar(scatter, ax=ax, label='Target label')
ax.text2D(0.05, 0.95, f'Training Accuracy: {train_accuracy:.2f} %', transform=ax.transAxes, fontsize=12, verticalalignment='top')
plt.show()

# %% [markdown]
# ### 3. Even more dimensions

# %%
# Import some data to play with
iris = sk.datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
display(iris_df)
X = iris_df.iloc[:,:4]
display(X)
y = iris.target
print("Number of samples ::", X.shape[0])
print("Number of features ::", X.shape[1])
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
# Number of samples :: 150
# Number of features :: 4

# %%
X_scaled = StandardScaler().fit_transform(X)

clf = SVC(kernel='linear', random_state=0)
clf.fit(X_scaled, y)
y_pred = clf.predict(X_scaled)

accuracy = accuracy_score(y, y_pred) * 100
print(f"Accuracy of SVM model: {accuracy:.2f}%")

df_scaled = pd.DataFrame(X_scaled, columns=['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'])

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

scatter_actual = ax.scatter(
    df_scaled['sepal length (cm)'],
    df_scaled['sepal width (cm)'],
    df_scaled['petal length (cm)'],
    c=y,  
    cmap='viridis',
    s=petal_width * 50, 
    alpha=0.5,
    label='Actual Classes'
)

scatter_predicted = ax.scatter(
    df_scaled['sepal length (cm)'],
    df_scaled['sepal width (cm)'],
    df_scaled['petal length (cm)'],
    c=y_pred,  
    cmap='coolwarm',
    s=petal_width * 50,  
    alpha=0.3,
    marker='x',
    label='Predicted Classes'
)

ax.set_xlabel('Sepal Length (cm)')
ax.set_ylabel('Sepal Width (cm)')
ax.set_zlabel('Petal Length (cm)')
ax.set_title('SVM Classification on Iris Dataset (4D Visualization)')

ax.legend(loc='upper left')

cbar_actual = fig.colorbar(scatter_actual, ax=ax)
cbar_actual.set_label('Actual Class Label', rotation=270)

plt.show()
# Out:
# Accuracy of SVM model: 96.67%
